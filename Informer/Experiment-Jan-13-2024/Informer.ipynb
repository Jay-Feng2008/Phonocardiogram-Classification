# %%
import tensorflow as tf
from tensorflow import keras
import numpy as np
# from layers import PositionalEmbedding, MultiHeadSelfAttention, ConvLayer
import datetime
from tensorflow.python.keras.engine.base_layer import Layer
from math import sqrt

# %%
f = np.load("mfcc_fixed.npz")
X, Y = f['X'], f['Y']
X_train =  X[0:900]
Y_train =  Y[0:900]        # fold 10


x_test, y_test = X[900:1000], Y[900:1000]
x_train, y_train = X_train[0:800], Y_train[0:800]
x_val, y_val= X_train[800:900], Y_train[800:900]

# %%
batch_size = 32

train_dataset = tf.data.Dataset.from_tensor_slices((x_train, y_train))
train_dataset = train_dataset.shuffle(buffer_size=800, reshuffle_each_iteration=True).batch(batch_size, drop_remainder=True)
val_dataset = tf.data.Dataset.from_tensor_slices((x_val, y_val))
val_dataset = val_dataset.shuffle(buffer_size=800, reshuffle_each_iteration=True).batch(batch_size, drop_remainder=True)
test_dataset = tf.data.Dataset.from_tensor_slices((x_test, y_test))
test_dataset = test_dataset.shuffle(buffer_size=800, reshuffle_each_iteration=True).batch(batch_size, drop_remainder=True)


x = x_train[0:batch_size]
x_rank = tf.rank(x).numpy()
x_norm_resize_shape = [batch_size] + list(tf.ones(tf.rank(x), dtype=tf.int32).numpy())[1:]

# %%
class ProbAttention(Layer):
    def __init__(self, mask_flag=True, factor=5, scale=None, attention_dropout=0.1):
        super(ProbAttention, self).__init__()
        self.factor = factor
        self.scale = scale
        self.mask_flag = mask_flag
        self.dropout = tf.keras.layers.Dropout(attention_dropout)

    def _prob_QK(self, Q, K, sample_k, n_top):
        # Q [B, H, L, D]
        B, H, L, E = K.shape
        _, _, S, _ = Q.shape

        # calculate the sampled Q_K
        K_expand = tf.broadcast_to(tf.expand_dims(K, -3), (B, H, S, L, E))

        indx_q_seq = tf.random.uniform((S,), maxval=L, dtype=tf.int32)
        indx_k_seq = tf.random.uniform((sample_k,), maxval=L, dtype=tf.int32)

        K_sample = tf.gather(K_expand, tf.range(S), axis=2)

        K_sample = tf.gather(K_sample, indx_q_seq, axis=2)
        K_sample = tf.gather(K_sample, indx_k_seq, axis=3)

        Q_K_sample = tf.squeeze(tf.matmul(tf.expand_dims(Q, -2), tf.einsum("...ij->...ji", K_sample)))
        # find the Top_k query with sparisty measurement
        M = tf.math.reduce_max(Q_K_sample, axis=-1) - tf.raw_ops.Div(x=tf.reduce_sum(Q_K_sample, axis=-1), y=L)
        M_top = tf.math.top_k(M, n_top, sorted=False)[1]
        batch_indexes = tf.tile(tf.range(Q.shape[0])[:, tf.newaxis, tf.newaxis], (1, Q.shape[1], n_top))
        head_indexes = tf.tile(tf.range(Q.shape[1])[tf.newaxis, :, tf.newaxis], (Q.shape[0], 1, n_top))

        idx = tf.stack(values=[batch_indexes, head_indexes, M_top], axis=-1)

        # use the reduced Q to calculate Q_K
        Q_reduce = tf.gather_nd(Q, idx)

        Q_K = tf.matmul(Q_reduce, tf.transpose(K, [0, 1, 3, 2]))

        return Q_K, M_top
    
    
    def _get_initial_context(self, V, L_Q):
        B, H, L_V, D = V.shape
        if not self.mask_flag:
            V_sum = tf.reduce_sum(V, -2)
            contex = tf.identity(tf.broadcast_to(tf.expand_dims(V_sum, -2), [B, H, L_Q, V_sum.shape[-1]]))
        else:  # use mask
            assert (L_Q == L_V)  # requires that L_Q == L_V, i.e. for self-attention only
            contex = tf.math.cumsum(V, axis=-1)
        return contex

    def _update_context(self, context_in, V, scores, index, L_Q):
        B, H, L_V, D = V.shape

        if self.mask_flag:
            attn_mask = ProbMask(B, H, L_Q, index, scores)

            # scores.masked_fill_(attn_mask.mask, -np.inf)
            num = 3.4 * math.pow(10, 38)
            scores = (scores * attn_mask.mask) + (-((attn_mask.mask * num + num) - num))

        attn = tf.keras.activations.softmax(scores, axis=-1)  # nn.Softmax(dim=-1)(scores)
        batch_indexes = tf.tile(tf.range(V.shape[0])[:, tf.newaxis, tf.newaxis], (1, V.shape[1], index.shape[-1]))
        head_indexes = tf.tile(tf.range(V.shape[1])[tf.newaxis, :, tf.newaxis], (V.shape[0], 1, index.shape[-1]))

        idx = tf.stack(values=[batch_indexes, head_indexes, index], axis=-1)

        context_in = tf.tensor_scatter_nd_update(context_in, idx, tf.matmul(attn, V))

        return tf.convert_to_tensor(context_in)

    def call(self, inputs, attn_mask=None):
        queries, keys, values = inputs
        B, L, H, D = queries.shape
        _, S, _, _ = keys.shape

        queries = tf.reshape(queries, (B, H, L, -1))
        keys = tf.reshape(keys, (B, H, S, -1))
        values = tf.reshape(values, (B, H, S, -1))

        U = self.factor * np.ceil(np.log(S)).astype('int').item()
        u = self.factor * np.ceil(np.log(L)).astype('int').item()

        scores_top, index = self._prob_QK(queries, keys, u, U)
        # add scale factor
        scale = self.scale or 1. / sqrt(D)
        if scale is not None:
            scores_top = scores_top * scale
        # get the context
        context = self._get_initial_context(values, L)
        # update the context with selected top_k queries
        context = self._update_context(context, values, scores_top, index, L)

        return context


class AttentionLayer(Layer):
    def __init__(self, attention, d_model, n_heads, d_keys=None,
                 d_values=None):
        super(AttentionLayer, self).__init__()

        d_keys = d_keys or (d_model//n_heads)
        d_values = d_values or (d_model//n_heads)
        self.d_model = d_model

        self.inner_attention = attention
        self.query_projection = tf.keras.layers.Dense(d_keys * n_heads)
        self.key_projection = tf.keras.layers.Dense(d_keys * n_heads)
        self.value_projection = tf.keras.layers.Dense(d_values * n_heads)
        self.out_projection = tf.keras.layers.Dense(d_model)
        self.n_heads = n_heads

    def build(self, input_shape):
        print(input_shape)
        B, L, _ = input_shape[0]
        _, S, _ = input_shape[1]
        H = self.n_heads

        self.queries = self.add_weight(shape=(B, L, H, self.d_model),
                                 initializer='random_normal',
                                 trainable=True)

        self.keys = self.add_weight(shape=(B, S, H, self.d_model),
                                       initializer='random_normal',
                                       trainable=True)

        self.values = self.add_weight(shape=(B, S, H, self.d_model),
                                       initializer='random_normal',
                                       trainable=True)

    def call(self, inputs, attn_mask=None):
        queries, keys, values = inputs
        B, L, _ = queries.shape
        _, S, _ = keys.shape
        H = self.n_heads

        self.queries = tf.reshape(self.query_projection(queries), (B, L, H, -1))
        self.keys = tf.reshape(self.key_projection(keys), (B, S, H, -1))
        self.values = tf.reshape(self.value_projection(values), (B, S, H, -1))

        out = tf.reshape(self.inner_attention([self.queries, self.keys, self.values], attn_mask=attn_mask), (B, L, -1))

        return self.out_projection(out)
    
    
class ConvLayer(Layer):
    def __init__(self, c_in):
        super(ConvLayer, self).__init__()
        self.downConv = tf.keras.layers.Conv1D(
                                  filters=c_in,
                                  kernel_size=3,
                                  padding='causal')
        self.norm = tf.keras.layers.BatchNormalization()
        self.activation = tf.keras.layers.ELU()
        self.maxPool = tf.keras.layers.MaxPool1D(pool_size=3, strides=2)

    def call(self, x, **kargs):
        x = self.downConv(x)
        x = self.norm(x)
        x = self.activation(x)
        x = self.maxPool(x)
        return x


class EncoderLayer(Layer):
    def __init__(self, attention, d_model, d_ff=None, dropout=0.1, activation="relu"):
        super(EncoderLayer, self).__init__()
        d_ff = d_ff or 4*d_model
        self.attention = attention
        self.conv1 = tf.keras.layers.Conv1D(filters=d_ff, kernel_size=1)
        self.conv2 = tf.keras.layers.Conv1D(filters=d_model, kernel_size=1)
        self.norm1 = tf.keras.layers.LayerNormalization()
        self.norm2 = tf.keras.layers.LayerNormalization()
        self.dropout = tf.keras.layers.Dropout(dropout)
        self.activation = tf.keras.activations.relu if activation == "relu" else tf.keras.activations.gelu

    def call(self, x, attn_mask=None):
        # x [B, L, D]
        print(x.shape)
        print(self.dropout(self.attention(
            [x, x, x],
            attn_mask = attn_mask
        )).shape)
        x = x + self.dropout(self.attention(
            [x, x, x],
            attn_mask = attn_mask
        ))

        y = x = self.norm1(x)
        y = self.dropout(self.activation(self.conv1(y)))
        y = self.dropout(self.conv2(y))
        return self.norm2(x+y)


class Encoder(Layer):
    def __init__(self, attn_layers, conv_layers=None, norm_layer=None):
        super(Encoder, self).__init__()
        self.attn_layers = attn_layers
        self.conv_layers = conv_layers if conv_layers is not None else None
        self.norm = norm_layer

    def call(self, x, attn_mask=None):
        # x [B, L, D]
        if self.conv_layers is not None:
            for attn_layer, conv_layer in zip(self.attn_layers, self.conv_layers):
                x = attn_layer(x, attn_mask=attn_mask)
                x = conv_layer(x)
            x = self.attn_layers[-1](x)
        else:
            for attn_layer in self.attn_layers:
                x = attn_layer(x, attn_mask=attn_mask)

        if self.norm is not None:
            x = self.norm(x)

        return x
    
    
def positional_encoding(length, depth):
        depth = depth/2

        positions = np.arange(length)[:, np.newaxis]     # (seq, 1)
        depths = np.arange(depth)[np.newaxis, :]/depth   # (1, depth)

        angle_rates = 1 / (10000**depths)         # (1, depth)
        angle_rads = positions * angle_rates      # (pos, depth)

        pos_encoding = np.concatenate(
            [np.sin(angle_rads), np.cos(angle_rads)],
            axis=-1)

        return tf.cast(pos_encoding, dtype=tf.float32)    
    
class PositionalEmbedding(tf.keras.layers.Layer):
    def __init__(self, d_model):
        super(PositionalEmbedding, self).__init__()
        self.d_model = d_model
        self.embd = keras.layers.Conv1D(filters=d_model, kernel_size=1)
        self.pos_encoding = positional_encoding(length=2048, depth=d_model)

    def call(self, x):
        length = tf.shape(x)[1]
        x = self.embd(x)
        x *= tf.math.sqrt(tf.cast(self.d_model, tf.float32))
        x = x + self.pos_encoding[tf.newaxis, :length, :]
        return x

# %%
class Informer(keras.Model):

    def __init__(self, seq_len, batch_size,
                 factor=5, d_model=512, n_heads=8, e_layers=2, d_layers=2, d_ff=512,
                 dropout=0.1, attn='prob', activation='gelu'):
        super(Informer, self).__init__()
        self.attn = attn
        self.seq_len = seq_len
        self.batch_size = batch_size
        self.gap = keras.layers.GlobalAveragePooling1D(data_format="channels_first")
        self.dense = keras.layers.Dense(5, activation='softmax')
        self.embd = PositionalEmbedding(d_model=512)

        # Attention
        Attn = ProbAttention if attn == 'prob' else FullAttention
        # Encoder
        self.encoder = Encoder(
            [
                EncoderLayer(
                    AttentionLayer(Attn(False, factor, attention_dropout=dropout),
                                   d_model, n_heads),
                    d_model,
                    d_ff,
                    dropout=dropout,
                    activation=activation
                ) for l in range(e_layers)
            ],
            [
                ConvLayer(
                    d_model
                ) for l in range(e_layers - 1)
            ],
            norm_layer=tf.keras.layers.LayerNormalization()
        )
        
    def call(self, inputs):

        x = inputs
        x = self.embd(x)

#         x.set_shape((self.batch_size, self.seq_len, 512))

        x = self.encoder(x)

        x = self.gap(x)
        x = self.dense(x)

        return x

# %%
model = Informer(54, 32)

# %%
loss_fn = keras.losses.SparseCategoricalCrossentropy(from_logits=False)
lds = lambda x, y: tf.math.reduce_sum(keras.losses.kl_divergence(x, y))
acc_metric = keras.metrics.SparseCategoricalAccuracy()
optimizer = keras.optimizers.Adam(learning_rate=1e-4)

# %%
es_callback = keras.callbacks.EarlyStopping(
                                            monitor="val_loss",
                                            min_delta=0,
                                            patience=100,
                                            verbose=1,
                                            mode="auto",
                                            baseline=None,
                                            restore_best_weights=True,
                                            start_from_epoch=0)

model.compile(optimizer=optimizer, loss=keras.losses.SparseCategoricalCrossentropy(from_logits=False), metrics=['accuracy'])

# %%
model.fit(train_dataset, validation_data=val_dataset, batch_size=batch_size, epochs=2000,
          callbacks=[es_callback])
# Out:
# Epoch 1/2000
# (32, 54, 512)
# [TensorShape([32, 54, 512]), TensorShape([32, 54, 512]), TensorShape([32, 54, 512])]
# (32, 54, 512)
# (32, 26, 512)
# [TensorShape([32, 26, 512]), TensorShape([32, 26, 512]), TensorShape([32, 26, 512])]
# (32, 26, 512)
# (32, 54, 512)
# (32, 54, 512)
# (32, 26, 512)
# (32, 26, 512)
# 25/25 [==============================] - ETA: 0s - loss: 1.6094 - accuracy: 0.1937(32, 54, 512)
# (32, 54, 512)
# (32, 26, 512)
# (32, 26, 512)
# 25/25 [==============================] - 8s 46ms/step - loss: 1.6094 - accuracy: 0.1937 - val_loss: 1.6093 - val_accuracy: 0.2396
# Epoch 2/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 1.6091 - accuracy: 0.2850 - val_loss: 1.6088 - val_accuracy: 0.4375
# Epoch 3/2000
# 25/25 [==============================] - 0s 15ms/step - loss: 1.6072 - accuracy: 0.5400 - val_loss: 1.6059 - val_accuracy: 0.4792
# Epoch 4/2000
# 25/25 [==============================] - 0s 15ms/step - loss: 1.6035 - accuracy: 0.5800 - val_loss: 1.6033 - val_accuracy: 0.4688
# Epoch 5/2000
# 25/25 [==============================] - 0s 15ms/step - loss: 1.5989 - accuracy: 0.5675 - val_loss: 1.5957 - val_accuracy: 0.5729
# Epoch 6/2000
# 25/25 [==============================] - 0s 15ms/step - loss: 1.5934 - accuracy: 0.5900 - val_loss: 1.5870 - val_accuracy: 0.6354
# Epoch 7/2000
# 25/25 [==============================] - 0s 15ms/step - loss: 1.5859 - accuracy: 0.6650 - val_loss: 1.5820 - val_accuracy: 0.6667
# Epoch 8/2000
# 25/25 [==============================] - 0s 15ms/step - loss: 1.5776 - accuracy: 0.6925 - val_loss: 1.5694 - val_accuracy: 0.7292
# Epoch 9/2000
# 25/25 [==============================] - 0s 15ms/step - loss: 1.5660 - accuracy: 0.7412 - val_loss: 1.5611 - val_accuracy: 0.6875
# Epoch 10/2000
# 25/25 [==============================] - 0s 15ms/step - loss: 1.5591 - accuracy: 0.7325 - val_loss: 1.5590 - val_accuracy: 0.6667
# Epoch 11/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 1.5486 - accuracy: 0.7500 - val_loss: 1.5458 - val_accuracy: 0.6771
# Epoch 12/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 1.5421 - accuracy: 0.7312 - val_loss: 1.5479 - val_accuracy: 0.6146
# Epoch 13/2000
# 25/25 [==============================] - 0s 15ms/step - loss: 1.5290 - accuracy: 0.7713 - val_loss: 1.5365 - val_accuracy: 0.6354
# Epoch 14/2000
# 25/25 [==============================] - 0s 15ms/step - loss: 1.5250 - accuracy: 0.7588 - val_loss: 1.5298 - val_accuracy: 0.6562
# Epoch 15/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 1.5168 - accuracy: 0.7262 - val_loss: 1.5463 - val_accuracy: 0.4688
# Epoch 16/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 1.5035 - accuracy: 0.7650 - val_loss: 1.5441 - val_accuracy: 0.4271
# Epoch 17/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 1.4861 - accuracy: 0.8112 - val_loss: 1.4805 - val_accuracy: 0.7500
# Epoch 18/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 1.4787 - accuracy: 0.8175 - val_loss: 1.4706 - val_accuracy: 0.7917
# Epoch 19/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 1.4622 - accuracy: 0.8338 - val_loss: 1.4916 - val_accuracy: 0.6458
# Epoch 20/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 1.4521 - accuracy: 0.8112 - val_loss: 1.4620 - val_accuracy: 0.7500
# Epoch 21/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 1.4355 - accuracy: 0.8388 - val_loss: 1.4770 - val_accuracy: 0.6458
# Epoch 22/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 1.4132 - accuracy: 0.8775 - val_loss: 1.4261 - val_accuracy: 0.7500
# Epoch 23/2000
# 25/25 [==============================] - 0s 15ms/step - loss: 1.4076 - accuracy: 0.8662 - val_loss: 1.4100 - val_accuracy: 0.8021
# Epoch 24/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 1.3947 - accuracy: 0.8537 - val_loss: 1.4504 - val_accuracy: 0.6042
# Epoch 25/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 1.3752 - accuracy: 0.8800 - val_loss: 1.3888 - val_accuracy: 0.8438
# Epoch 26/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 1.3588 - accuracy: 0.8712 - val_loss: 1.3618 - val_accuracy: 0.8021
# Epoch 27/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 1.3455 - accuracy: 0.8600 - val_loss: 1.3411 - val_accuracy: 0.8646
# Epoch 28/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 1.3345 - accuracy: 0.8512 - val_loss: 1.3143 - val_accuracy: 0.8438
# Epoch 29/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 1.3189 - accuracy: 0.8662 - val_loss: 1.3760 - val_accuracy: 0.6979
# Epoch 30/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 1.3051 - accuracy: 0.8600 - val_loss: 1.2987 - val_accuracy: 0.8438
# Epoch 31/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 1.2898 - accuracy: 0.8725 - val_loss: 1.2549 - val_accuracy: 0.8646
# Epoch 32/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 1.2641 - accuracy: 0.8850 - val_loss: 1.2739 - val_accuracy: 0.8125
# Epoch 33/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 1.2568 - accuracy: 0.8825 - val_loss: 1.2950 - val_accuracy: 0.6875
# Epoch 34/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 1.2419 - accuracy: 0.8737 - val_loss: 1.2315 - val_accuracy: 0.8958
# Epoch 35/2000
# 25/25 [==============================] - 0s 15ms/step - loss: 1.2076 - accuracy: 0.8913 - val_loss: 1.1899 - val_accuracy: 0.8438
# Epoch 36/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 1.1973 - accuracy: 0.9062 - val_loss: 1.1921 - val_accuracy: 0.8542
# Epoch 37/2000
# 25/25 [==============================] - 0s 15ms/step - loss: 1.1821 - accuracy: 0.9038 - val_loss: 1.1546 - val_accuracy: 0.8750
# Epoch 38/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 1.1611 - accuracy: 0.9225 - val_loss: 1.1611 - val_accuracy: 0.8854
# Epoch 39/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 1.1537 - accuracy: 0.8863 - val_loss: 1.1590 - val_accuracy: 0.8958
# Epoch 40/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 1.1267 - accuracy: 0.9137 - val_loss: 1.1387 - val_accuracy: 0.8438
# Epoch 41/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 1.1148 - accuracy: 0.9050 - val_loss: 1.3090 - val_accuracy: 0.6042
# Epoch 42/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 1.1171 - accuracy: 0.9162 - val_loss: 1.1022 - val_accuracy: 0.8542
# Epoch 43/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 1.0970 - accuracy: 0.9075 - val_loss: 1.1080 - val_accuracy: 0.9062
# Epoch 44/2000
# 25/25 [==============================] - 0s 15ms/step - loss: 1.0763 - accuracy: 0.9150 - val_loss: 1.0787 - val_accuracy: 0.9062
# Epoch 45/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 1.0580 - accuracy: 0.9312 - val_loss: 1.0514 - val_accuracy: 0.9062
# Epoch 46/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 1.0378 - accuracy: 0.9150 - val_loss: 1.0287 - val_accuracy: 0.8958
# Epoch 47/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 1.0178 - accuracy: 0.9200 - val_loss: 1.0170 - val_accuracy: 0.9062
# Epoch 48/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.9917 - accuracy: 0.9375 - val_loss: 0.9725 - val_accuracy: 0.9167
# Epoch 49/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.9891 - accuracy: 0.9162 - val_loss: 1.0184 - val_accuracy: 0.8542
# Epoch 50/2000
# 25/25 [==============================] - 0s 16ms/step - loss: 0.9564 - accuracy: 0.9375 - val_loss: 0.9486 - val_accuracy: 0.9062
# Epoch 51/2000
# 25/25 [==============================] - 0s 15ms/step - loss: 0.9447 - accuracy: 0.9362 - val_loss: 0.9183 - val_accuracy: 0.9271
# Epoch 52/2000
# 25/25 [==============================] - 0s 15ms/step - loss: 0.9353 - accuracy: 0.9413 - val_loss: 0.9175 - val_accuracy: 0.9167
# Epoch 53/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.9236 - accuracy: 0.9350 - val_loss: 0.9220 - val_accuracy: 0.9479
# Epoch 54/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.9150 - accuracy: 0.9337 - val_loss: 1.0741 - val_accuracy: 0.8021
# Epoch 55/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.8860 - accuracy: 0.9388 - val_loss: 0.8567 - val_accuracy: 0.9583
# Epoch 56/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.8755 - accuracy: 0.9413 - val_loss: 0.8532 - val_accuracy: 0.9271
# Epoch 57/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.8495 - accuracy: 0.9425 - val_loss: 0.8155 - val_accuracy: 0.9583
# Epoch 58/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.8246 - accuracy: 0.9450 - val_loss: 0.8358 - val_accuracy: 0.9375
# Epoch 59/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.8154 - accuracy: 0.9563 - val_loss: 0.8436 - val_accuracy: 0.9167
# Epoch 60/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.7967 - accuracy: 0.9638 - val_loss: 0.8715 - val_accuracy: 0.9271
# Epoch 61/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.7962 - accuracy: 0.9525 - val_loss: 0.8202 - val_accuracy: 0.9271
# Epoch 62/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.7832 - accuracy: 0.9463 - val_loss: 0.7853 - val_accuracy: 0.9375
# Epoch 63/2000
# 25/25 [==============================] - 0s 15ms/step - loss: 0.7608 - accuracy: 0.9538 - val_loss: 0.7795 - val_accuracy: 0.9062
# Epoch 64/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.7299 - accuracy: 0.9650 - val_loss: 0.7220 - val_accuracy: 0.9375
# Epoch 65/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.7125 - accuracy: 0.9463 - val_loss: 0.7290 - val_accuracy: 0.9271
# Epoch 66/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.7063 - accuracy: 0.9525 - val_loss: 0.7302 - val_accuracy: 0.9062
# Epoch 67/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.6923 - accuracy: 0.9488 - val_loss: 0.7238 - val_accuracy: 0.9271
# Epoch 68/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.6836 - accuracy: 0.9500 - val_loss: 0.7077 - val_accuracy: 0.9479
# Epoch 69/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.6976 - accuracy: 0.9600 - val_loss: 0.6925 - val_accuracy: 0.8958
# Epoch 70/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.6802 - accuracy: 0.9375 - val_loss: 0.7802 - val_accuracy: 0.8646
# Epoch 71/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.6654 - accuracy: 0.9425 - val_loss: 0.7167 - val_accuracy: 0.9375
# Epoch 72/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.6240 - accuracy: 0.9563 - val_loss: 0.6466 - val_accuracy: 0.9375
# Epoch 73/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.6103 - accuracy: 0.9500 - val_loss: 0.6339 - val_accuracy: 0.9479
# Epoch 74/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.6103 - accuracy: 0.9538 - val_loss: 0.6495 - val_accuracy: 0.9375
# Epoch 75/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.5980 - accuracy: 0.9525 - val_loss: 0.6306 - val_accuracy: 0.9062
# Epoch 76/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.5804 - accuracy: 0.9500 - val_loss: 0.5911 - val_accuracy: 0.9271
# Epoch 77/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.5586 - accuracy: 0.9575 - val_loss: 0.6088 - val_accuracy: 0.9375
# Epoch 78/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.5531 - accuracy: 0.9625 - val_loss: 0.6282 - val_accuracy: 0.8958
# Epoch 79/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.5386 - accuracy: 0.9625 - val_loss: 0.6285 - val_accuracy: 0.9583
# Epoch 80/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.5581 - accuracy: 0.9663 - val_loss: 0.5826 - val_accuracy: 0.9375
# Epoch 81/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.5159 - accuracy: 0.9700 - val_loss: 0.5280 - val_accuracy: 0.9375
# Epoch 82/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.5274 - accuracy: 0.9638 - val_loss: 0.6080 - val_accuracy: 0.9583
# Epoch 83/2000
# 25/25 [==============================] - 0s 15ms/step - loss: 0.5065 - accuracy: 0.9737 - val_loss: 0.5162 - val_accuracy: 0.9479
# Epoch 84/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.4869 - accuracy: 0.9775 - val_loss: 0.5169 - val_accuracy: 0.9375
# Epoch 85/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.4741 - accuracy: 0.9712 - val_loss: 0.4902 - val_accuracy: 0.9375
# Epoch 86/2000
# 25/25 [==============================] - 0s 15ms/step - loss: 0.4909 - accuracy: 0.9563 - val_loss: 0.4792 - val_accuracy: 0.9375
# Epoch 87/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.4495 - accuracy: 0.9800 - val_loss: 0.4611 - val_accuracy: 0.9688
# Epoch 88/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.4214 - accuracy: 0.9812 - val_loss: 0.5619 - val_accuracy: 0.9062
# Epoch 89/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.4150 - accuracy: 0.9825 - val_loss: 0.4668 - val_accuracy: 0.9583
# Epoch 90/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.4081 - accuracy: 0.9837 - val_loss: 0.4181 - val_accuracy: 0.9792
# Epoch 91/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.4025 - accuracy: 0.9762 - val_loss: 0.5106 - val_accuracy: 0.9479
# Epoch 92/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.4142 - accuracy: 0.9725 - val_loss: 0.4191 - val_accuracy: 0.9583
# Epoch 93/2000
# 25/25 [==============================] - 0s 15ms/step - loss: 0.3701 - accuracy: 0.9787 - val_loss: 0.4153 - val_accuracy: 0.9583
# Epoch 94/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.3665 - accuracy: 0.9862 - val_loss: 0.4251 - val_accuracy: 0.9479
# Epoch 95/2000
# 25/25 [==============================] - 0s 15ms/step - loss: 0.3467 - accuracy: 0.9837 - val_loss: 0.3789 - val_accuracy: 0.9688
# Epoch 96/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.3594 - accuracy: 0.9812 - val_loss: 0.3863 - val_accuracy: 0.9688
# Epoch 97/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.3630 - accuracy: 0.9775 - val_loss: 0.4967 - val_accuracy: 0.9479
# Epoch 98/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.3547 - accuracy: 0.9825 - val_loss: 0.3923 - val_accuracy: 0.9479
# Epoch 99/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.3287 - accuracy: 0.9850 - val_loss: 0.3257 - val_accuracy: 0.9792
# Epoch 100/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.3376 - accuracy: 0.9862 - val_loss: 0.3860 - val_accuracy: 0.9583
# Epoch 101/2000
# 25/25 [==============================] - 0s 16ms/step - loss: 0.3343 - accuracy: 0.9862 - val_loss: 0.3709 - val_accuracy: 0.9479
# Epoch 102/2000
# 25/25 [==============================] - 0s 15ms/step - loss: 0.3243 - accuracy: 0.9850 - val_loss: 0.3426 - val_accuracy: 0.9792
# Epoch 103/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.3026 - accuracy: 0.9862 - val_loss: 0.3599 - val_accuracy: 0.9375
# Epoch 104/2000
# 25/25 [==============================] - 0s 17ms/step - loss: 0.2937 - accuracy: 0.9875 - val_loss: 0.2913 - val_accuracy: 0.9792
# Epoch 105/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.2839 - accuracy: 0.9875 - val_loss: 0.3002 - val_accuracy: 0.9792
# Epoch 106/2000
# 25/25 [==============================] - 0s 16ms/step - loss: 0.2827 - accuracy: 0.9862 - val_loss: 0.2779 - val_accuracy: 0.9792
# Epoch 107/2000
# 25/25 [==============================] - 0s 17ms/step - loss: 0.2640 - accuracy: 0.9950 - val_loss: 0.2767 - val_accuracy: 0.9896
# Epoch 108/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.2585 - accuracy: 0.9925 - val_loss: 0.2502 - val_accuracy: 1.0000
# Epoch 109/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.2581 - accuracy: 0.9925 - val_loss: 0.2772 - val_accuracy: 0.9688
# Epoch 110/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.2438 - accuracy: 0.9900 - val_loss: 0.2674 - val_accuracy: 0.9896
# Epoch 111/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.2455 - accuracy: 0.9912 - val_loss: 0.2693 - val_accuracy: 0.9896
# Epoch 112/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.2357 - accuracy: 0.9937 - val_loss: 0.3304 - val_accuracy: 0.9583
# Epoch 113/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.2674 - accuracy: 0.9812 - val_loss: 0.2637 - val_accuracy: 0.9792
# Epoch 114/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.2246 - accuracy: 0.9912 - val_loss: 0.2475 - val_accuracy: 0.9896
# Epoch 115/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.2169 - accuracy: 0.9925 - val_loss: 0.2308 - val_accuracy: 0.9583
# Epoch 116/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.2066 - accuracy: 0.9937 - val_loss: 0.2350 - val_accuracy: 0.9896
# Epoch 117/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.2178 - accuracy: 0.9912 - val_loss: 0.2552 - val_accuracy: 0.9792
# Epoch 118/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.2049 - accuracy: 0.9950 - val_loss: 0.2473 - val_accuracy: 0.9583
# Epoch 119/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.2047 - accuracy: 0.9912 - val_loss: 0.2628 - val_accuracy: 0.9688
# Epoch 120/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.2078 - accuracy: 0.9937 - val_loss: 0.2268 - val_accuracy: 0.9792
# Epoch 121/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.1943 - accuracy: 0.9912 - val_loss: 0.2306 - val_accuracy: 0.9792
# Epoch 122/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.2182 - accuracy: 0.9887 - val_loss: 0.2307 - val_accuracy: 0.9583
# Epoch 123/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.2231 - accuracy: 0.9900 - val_loss: 0.1994 - val_accuracy: 0.9688
# Epoch 124/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.1873 - accuracy: 0.9925 - val_loss: 0.2165 - val_accuracy: 0.9792
# Epoch 125/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.1777 - accuracy: 0.9975 - val_loss: 0.1840 - val_accuracy: 0.9896
# Epoch 126/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.1722 - accuracy: 0.9962 - val_loss: 0.1712 - val_accuracy: 0.9896
# Epoch 127/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.1712 - accuracy: 0.9950 - val_loss: 0.2215 - val_accuracy: 0.9688
# Epoch 128/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.1722 - accuracy: 0.9962 - val_loss: 0.1714 - val_accuracy: 1.0000
# Epoch 129/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.1640 - accuracy: 0.9962 - val_loss: 0.1972 - val_accuracy: 0.9688
# Epoch 130/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.1591 - accuracy: 0.9962 - val_loss: 0.2120 - val_accuracy: 0.9792
# Epoch 131/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.1524 - accuracy: 0.9937 - val_loss: 0.1997 - val_accuracy: 0.9792
# Epoch 132/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.1514 - accuracy: 0.9987 - val_loss: 0.1645 - val_accuracy: 0.9896
# Epoch 133/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.1515 - accuracy: 0.9987 - val_loss: 0.1661 - val_accuracy: 0.9792
# Epoch 134/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.1541 - accuracy: 0.9962 - val_loss: 0.2004 - val_accuracy: 0.9688
# Epoch 135/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.1452 - accuracy: 0.9937 - val_loss: 0.1737 - val_accuracy: 0.9896
# Epoch 136/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.1400 - accuracy: 0.9962 - val_loss: 0.1719 - val_accuracy: 0.9792
# Epoch 137/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.1345 - accuracy: 0.9962 - val_loss: 0.1650 - val_accuracy: 0.9688
# Epoch 138/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.1320 - accuracy: 0.9962 - val_loss: 0.1376 - val_accuracy: 1.0000
# Epoch 139/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.1305 - accuracy: 0.9975 - val_loss: 0.1500 - val_accuracy: 0.9896
# Epoch 140/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.1292 - accuracy: 0.9950 - val_loss: 0.1999 - val_accuracy: 0.9583
# Epoch 141/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.1337 - accuracy: 0.9950 - val_loss: 0.2259 - val_accuracy: 0.9375
# Epoch 142/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.1323 - accuracy: 0.9937 - val_loss: 0.2455 - val_accuracy: 0.9479
# Epoch 143/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.1253 - accuracy: 0.9962 - val_loss: 0.1338 - val_accuracy: 0.9896
# Epoch 144/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.1204 - accuracy: 0.9962 - val_loss: 0.1448 - val_accuracy: 0.9792
# Epoch 145/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.1185 - accuracy: 0.9962 - val_loss: 0.2707 - val_accuracy: 0.9479
# Epoch 146/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.1239 - accuracy: 0.9937 - val_loss: 0.1884 - val_accuracy: 0.9479
# Epoch 147/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.1195 - accuracy: 0.9950 - val_loss: 0.2069 - val_accuracy: 0.9688
# Epoch 148/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.1130 - accuracy: 0.9950 - val_loss: 0.1714 - val_accuracy: 0.9583
# Epoch 149/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.1085 - accuracy: 0.9987 - val_loss: 0.1389 - val_accuracy: 0.9792
# Epoch 150/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.1088 - accuracy: 0.9925 - val_loss: 0.1737 - val_accuracy: 0.9688
# Epoch 151/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.1086 - accuracy: 0.9962 - val_loss: 0.1366 - val_accuracy: 0.9792
# Epoch 152/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.1097 - accuracy: 0.9975 - val_loss: 0.1576 - val_accuracy: 0.9688
# Epoch 153/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0997 - accuracy: 0.9987 - val_loss: 0.1983 - val_accuracy: 0.9583
# Epoch 154/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.1027 - accuracy: 0.9950 - val_loss: 0.1442 - val_accuracy: 0.9688
# Epoch 155/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.1018 - accuracy: 0.9962 - val_loss: 0.1238 - val_accuracy: 1.0000
# Epoch 156/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.1003 - accuracy: 0.9975 - val_loss: 0.1346 - val_accuracy: 0.9792
# Epoch 157/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0985 - accuracy: 0.9962 - val_loss: 0.1254 - val_accuracy: 0.9896
# Epoch 158/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0965 - accuracy: 0.9962 - val_loss: 0.1538 - val_accuracy: 0.9583
# Epoch 159/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.1005 - accuracy: 0.9937 - val_loss: 0.1754 - val_accuracy: 0.9688
# Epoch 160/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.1319 - accuracy: 0.9887 - val_loss: 1.4511 - val_accuracy: 0.5104
# Epoch 161/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.1390 - accuracy: 0.9875 - val_loss: 0.1323 - val_accuracy: 0.9792
# Epoch 162/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.1116 - accuracy: 0.9900 - val_loss: 0.1457 - val_accuracy: 0.9688
# Epoch 163/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.1027 - accuracy: 0.9950 - val_loss: 0.0928 - val_accuracy: 1.0000
# Epoch 164/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0824 - accuracy: 0.9975 - val_loss: 0.1558 - val_accuracy: 0.9688
# Epoch 165/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0821 - accuracy: 0.9962 - val_loss: 0.1079 - val_accuracy: 0.9896
# Epoch 166/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0838 - accuracy: 0.9975 - val_loss: 0.1172 - val_accuracy: 1.0000
# Epoch 167/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0836 - accuracy: 0.9987 - val_loss: 0.1295 - val_accuracy: 0.9792
# Epoch 168/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0827 - accuracy: 0.9987 - val_loss: 0.1073 - val_accuracy: 0.9896
# Epoch 169/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0801 - accuracy: 0.9975 - val_loss: 0.1242 - val_accuracy: 0.9896
# Epoch 170/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0745 - accuracy: 0.9987 - val_loss: 0.1129 - val_accuracy: 0.9792
# Epoch 171/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0814 - accuracy: 0.9987 - val_loss: 0.1099 - val_accuracy: 0.9896
# Epoch 172/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0734 - accuracy: 0.9987 - val_loss: 0.0809 - val_accuracy: 0.9896
# Epoch 173/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0696 - accuracy: 0.9975 - val_loss: 0.1399 - val_accuracy: 0.9688
# Epoch 174/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0744 - accuracy: 0.9962 - val_loss: 0.1162 - val_accuracy: 0.9896
# Epoch 175/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0750 - accuracy: 0.9975 - val_loss: 0.0968 - val_accuracy: 1.0000
# Epoch 176/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0685 - accuracy: 0.9987 - val_loss: 0.0839 - val_accuracy: 1.0000
# Epoch 177/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0705 - accuracy: 0.9950 - val_loss: 0.0999 - val_accuracy: 0.9792
# Epoch 178/2000
# 25/25 [==============================] - 0s 15ms/step - loss: 0.0610 - accuracy: 1.0000 - val_loss: 0.0610 - val_accuracy: 1.0000
# Epoch 179/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0567 - accuracy: 1.0000 - val_loss: 0.0718 - val_accuracy: 1.0000
# Epoch 180/2000
# 25/25 [==============================] - 0s 15ms/step - loss: 0.0565 - accuracy: 1.0000 - val_loss: 0.0586 - val_accuracy: 1.0000
# Epoch 181/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0708 - accuracy: 0.9962 - val_loss: 0.0818 - val_accuracy: 1.0000
# Epoch 182/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0720 - accuracy: 0.9975 - val_loss: 0.1705 - val_accuracy: 0.9583
# Epoch 183/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0792 - accuracy: 0.9950 - val_loss: 0.1453 - val_accuracy: 0.9583
# Epoch 184/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0631 - accuracy: 0.9987 - val_loss: 0.0712 - val_accuracy: 0.9896
# Epoch 185/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0564 - accuracy: 1.0000 - val_loss: 0.0767 - val_accuracy: 0.9896
# Epoch 186/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0528 - accuracy: 0.9987 - val_loss: 0.0753 - val_accuracy: 0.9896
# Epoch 187/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0531 - accuracy: 0.9987 - val_loss: 0.0644 - val_accuracy: 1.0000
# Epoch 188/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0584 - accuracy: 0.9975 - val_loss: 0.1476 - val_accuracy: 0.9583
# Epoch 189/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0526 - accuracy: 1.0000 - val_loss: 0.0898 - val_accuracy: 0.9792
# Epoch 190/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0526 - accuracy: 0.9987 - val_loss: 0.0948 - val_accuracy: 0.9688
# Epoch 191/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0514 - accuracy: 0.9987 - val_loss: 0.1328 - val_accuracy: 0.9688
# Epoch 192/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0605 - accuracy: 0.9962 - val_loss: 0.1874 - val_accuracy: 0.9375
# Epoch 193/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.1036 - accuracy: 0.9812 - val_loss: 0.1275 - val_accuracy: 0.9792
# Epoch 194/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0827 - accuracy: 0.9937 - val_loss: 0.1031 - val_accuracy: 0.9896
# Epoch 195/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0659 - accuracy: 0.9962 - val_loss: 0.0861 - val_accuracy: 0.9896
# Epoch 196/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0542 - accuracy: 0.9975 - val_loss: 0.0800 - val_accuracy: 0.9896
# Epoch 197/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0496 - accuracy: 0.9987 - val_loss: 0.0538 - val_accuracy: 1.0000
# Epoch 198/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0443 - accuracy: 1.0000 - val_loss: 0.0715 - val_accuracy: 0.9896
# Epoch 199/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0446 - accuracy: 1.0000 - val_loss: 0.0642 - val_accuracy: 1.0000
# Epoch 200/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0425 - accuracy: 0.9987 - val_loss: 0.0599 - val_accuracy: 0.9896
# Epoch 201/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0431 - accuracy: 0.9987 - val_loss: 0.1071 - val_accuracy: 0.9792
# Epoch 202/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0532 - accuracy: 0.9925 - val_loss: 0.0597 - val_accuracy: 1.0000
# Epoch 203/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0521 - accuracy: 0.9962 - val_loss: 0.0809 - val_accuracy: 0.9792
# Epoch 204/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0459 - accuracy: 0.9975 - val_loss: 0.0859 - val_accuracy: 0.9792
# Epoch 205/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0425 - accuracy: 0.9987 - val_loss: 0.0535 - val_accuracy: 0.9896
# Epoch 206/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0373 - accuracy: 1.0000 - val_loss: 0.0736 - val_accuracy: 0.9896
# Epoch 207/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0372 - accuracy: 1.0000 - val_loss: 0.0759 - val_accuracy: 0.9792
# Epoch 208/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0355 - accuracy: 1.0000 - val_loss: 0.0713 - val_accuracy: 0.9896
# Epoch 209/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0353 - accuracy: 1.0000 - val_loss: 0.0754 - val_accuracy: 0.9896
# Epoch 210/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0353 - accuracy: 1.0000 - val_loss: 0.0553 - val_accuracy: 1.0000
# Epoch 211/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0329 - accuracy: 1.0000 - val_loss: 0.0522 - val_accuracy: 1.0000
# Epoch 212/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0332 - accuracy: 1.0000 - val_loss: 0.0753 - val_accuracy: 0.9896
# Epoch 213/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0348 - accuracy: 0.9987 - val_loss: 0.0706 - val_accuracy: 0.9792
# Epoch 214/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0342 - accuracy: 0.9975 - val_loss: 0.0597 - val_accuracy: 0.9792
# Epoch 215/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0333 - accuracy: 1.0000 - val_loss: 0.0690 - val_accuracy: 0.9792
# Epoch 216/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0479 - accuracy: 0.9962 - val_loss: 0.0903 - val_accuracy: 0.9896
# Epoch 217/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0425 - accuracy: 0.9975 - val_loss: 0.0766 - val_accuracy: 0.9896
# Epoch 218/2000
# 25/25 [==============================] - 0s 16ms/step - loss: 0.0392 - accuracy: 0.9962 - val_loss: 0.0469 - val_accuracy: 1.0000
# Epoch 219/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0319 - accuracy: 0.9987 - val_loss: 0.0440 - val_accuracy: 1.0000
# Epoch 220/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0282 - accuracy: 1.0000 - val_loss: 0.0544 - val_accuracy: 0.9896
# Epoch 221/2000
# 25/25 [==============================] - 0s 15ms/step - loss: 0.0265 - accuracy: 1.0000 - val_loss: 0.0428 - val_accuracy: 0.9896
# Epoch 222/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0278 - accuracy: 1.0000 - val_loss: 0.0356 - val_accuracy: 1.0000
# Epoch 223/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0271 - accuracy: 1.0000 - val_loss: 0.0427 - val_accuracy: 1.0000
# Epoch 224/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0255 - accuracy: 1.0000 - val_loss: 0.0376 - val_accuracy: 0.9896
# Epoch 225/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0251 - accuracy: 1.0000 - val_loss: 0.0512 - val_accuracy: 0.9896
# Epoch 226/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0269 - accuracy: 1.0000 - val_loss: 0.0367 - val_accuracy: 1.0000
# Epoch 227/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0256 - accuracy: 0.9987 - val_loss: 0.0404 - val_accuracy: 1.0000
# Epoch 228/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0462 - accuracy: 0.9962 - val_loss: 0.0481 - val_accuracy: 1.0000
# Epoch 229/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0427 - accuracy: 0.9950 - val_loss: 0.0550 - val_accuracy: 1.0000
# Epoch 230/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0320 - accuracy: 1.0000 - val_loss: 0.0406 - val_accuracy: 1.0000
# Epoch 231/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0445 - accuracy: 0.9937 - val_loss: 0.0781 - val_accuracy: 0.9896
# Epoch 232/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0385 - accuracy: 0.9987 - val_loss: 0.1777 - val_accuracy: 0.9583
# Epoch 233/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0418 - accuracy: 0.9937 - val_loss: 0.0861 - val_accuracy: 0.9792
# Epoch 234/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0320 - accuracy: 0.9975 - val_loss: 0.0719 - val_accuracy: 0.9896
# Epoch 235/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0262 - accuracy: 0.9987 - val_loss: 0.0357 - val_accuracy: 1.0000
# Epoch 236/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0242 - accuracy: 0.9987 - val_loss: 0.0624 - val_accuracy: 0.9896
# Epoch 237/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0233 - accuracy: 0.9987 - val_loss: 0.0637 - val_accuracy: 0.9896
# Epoch 238/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0227 - accuracy: 0.9987 - val_loss: 0.0792 - val_accuracy: 0.9792
# Epoch 239/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0221 - accuracy: 0.9987 - val_loss: 0.0756 - val_accuracy: 0.9688
# Epoch 240/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0259 - accuracy: 0.9987 - val_loss: 0.0908 - val_accuracy: 0.9688
# Epoch 241/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0293 - accuracy: 1.0000 - val_loss: 0.0818 - val_accuracy: 0.9688
# Epoch 242/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0270 - accuracy: 0.9987 - val_loss: 0.0513 - val_accuracy: 0.9792
# Epoch 243/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0242 - accuracy: 0.9975 - val_loss: 0.0297 - val_accuracy: 1.0000
# Epoch 244/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0259 - accuracy: 1.0000 - val_loss: 0.0661 - val_accuracy: 1.0000
# Epoch 245/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0428 - accuracy: 0.9950 - val_loss: 0.1157 - val_accuracy: 0.9583
# Epoch 246/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0618 - accuracy: 0.9887 - val_loss: 0.0902 - val_accuracy: 0.9792
# Epoch 247/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0511 - accuracy: 0.9900 - val_loss: 0.0758 - val_accuracy: 0.9792
# Epoch 248/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0407 - accuracy: 0.9975 - val_loss: 0.0380 - val_accuracy: 1.0000
# Epoch 249/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0347 - accuracy: 0.9975 - val_loss: 0.1615 - val_accuracy: 0.9583
# Epoch 250/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0249 - accuracy: 1.0000 - val_loss: 0.0482 - val_accuracy: 0.9896
# Epoch 251/2000
# 25/25 [==============================] - 0s 15ms/step - loss: 0.0238 - accuracy: 0.9987 - val_loss: 0.0530 - val_accuracy: 0.9896
# Epoch 252/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0197 - accuracy: 1.0000 - val_loss: 0.0462 - val_accuracy: 0.9896
# Epoch 253/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0179 - accuracy: 1.0000 - val_loss: 0.0534 - val_accuracy: 0.9792
# Epoch 254/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0172 - accuracy: 1.0000 - val_loss: 0.0555 - val_accuracy: 0.9792
# Epoch 255/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0177 - accuracy: 1.0000 - val_loss: 0.0356 - val_accuracy: 0.9896
# Epoch 256/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0165 - accuracy: 1.0000 - val_loss: 0.0349 - val_accuracy: 1.0000
# Epoch 257/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0162 - accuracy: 1.0000 - val_loss: 0.0283 - val_accuracy: 1.0000
# Epoch 258/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0161 - accuracy: 1.0000 - val_loss: 0.0307 - val_accuracy: 0.9896
# Epoch 259/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0178 - accuracy: 1.0000 - val_loss: 0.0586 - val_accuracy: 0.9896
# Epoch 260/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0203 - accuracy: 1.0000 - val_loss: 0.0643 - val_accuracy: 0.9792
# Epoch 261/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0164 - accuracy: 1.0000 - val_loss: 0.0328 - val_accuracy: 0.9896
# Epoch 262/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0148 - accuracy: 1.0000 - val_loss: 0.0371 - val_accuracy: 0.9896
# Epoch 263/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0148 - accuracy: 1.0000 - val_loss: 0.0277 - val_accuracy: 1.0000
# Epoch 264/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0141 - accuracy: 1.0000 - val_loss: 0.0482 - val_accuracy: 0.9792
# Epoch 265/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0143 - accuracy: 1.0000 - val_loss: 0.0742 - val_accuracy: 0.9792
# Epoch 266/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0159 - accuracy: 0.9987 - val_loss: 0.0649 - val_accuracy: 0.9792
# Epoch 267/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0149 - accuracy: 0.9987 - val_loss: 0.0574 - val_accuracy: 0.9792
# Epoch 268/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0137 - accuracy: 1.0000 - val_loss: 0.0499 - val_accuracy: 0.9792
# Epoch 269/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0137 - accuracy: 0.9987 - val_loss: 0.0430 - val_accuracy: 0.9792
# Epoch 270/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0132 - accuracy: 0.9987 - val_loss: 0.0547 - val_accuracy: 0.9792
# Epoch 271/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0134 - accuracy: 0.9987 - val_loss: 0.0266 - val_accuracy: 0.9896
# Epoch 272/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0128 - accuracy: 0.9987 - val_loss: 0.0468 - val_accuracy: 0.9896
# Epoch 273/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0132 - accuracy: 0.9987 - val_loss: 0.0498 - val_accuracy: 0.9896
# Epoch 274/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0134 - accuracy: 0.9987 - val_loss: 0.0582 - val_accuracy: 0.9792
# Epoch 275/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0134 - accuracy: 0.9987 - val_loss: 0.0516 - val_accuracy: 0.9896
# Epoch 276/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0122 - accuracy: 0.9987 - val_loss: 0.0506 - val_accuracy: 0.9792
# Epoch 277/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0124 - accuracy: 0.9987 - val_loss: 0.0491 - val_accuracy: 0.9896
# Epoch 278/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0118 - accuracy: 0.9987 - val_loss: 0.0464 - val_accuracy: 0.9896
# Epoch 279/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0113 - accuracy: 0.9987 - val_loss: 0.0416 - val_accuracy: 0.9896
# Epoch 280/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0114 - accuracy: 1.0000 - val_loss: 0.0471 - val_accuracy: 0.9896
# Epoch 281/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0119 - accuracy: 1.0000 - val_loss: 0.0444 - val_accuracy: 0.9896
# Epoch 282/2000
# 25/25 [==============================] - 0s 15ms/step - loss: 0.0107 - accuracy: 1.0000 - val_loss: 0.0261 - val_accuracy: 0.9896
# Epoch 283/2000
# 25/25 [==============================] - 0s 15ms/step - loss: 0.0103 - accuracy: 1.0000 - val_loss: 0.0207 - val_accuracy: 1.0000
# Epoch 284/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0137 - accuracy: 0.9987 - val_loss: 0.0809 - val_accuracy: 0.9792
# Epoch 285/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0123 - accuracy: 0.9987 - val_loss: 0.0384 - val_accuracy: 0.9896
# Epoch 286/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0110 - accuracy: 0.9987 - val_loss: 0.0442 - val_accuracy: 0.9896
# Epoch 287/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0109 - accuracy: 0.9987 - val_loss: 0.0571 - val_accuracy: 0.9896
# Epoch 288/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0104 - accuracy: 0.9987 - val_loss: 0.0540 - val_accuracy: 0.9896
# Epoch 289/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0108 - accuracy: 0.9987 - val_loss: 0.0614 - val_accuracy: 0.9792
# Epoch 290/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0109 - accuracy: 0.9987 - val_loss: 0.0459 - val_accuracy: 0.9896
# Epoch 291/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0109 - accuracy: 0.9987 - val_loss: 0.0700 - val_accuracy: 0.9792
# Epoch 292/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0102 - accuracy: 0.9987 - val_loss: 0.0627 - val_accuracy: 0.9688
# Epoch 293/2000
# 25/25 [==============================] - 0s 15ms/step - loss: 0.0099 - accuracy: 0.9987 - val_loss: 0.0591 - val_accuracy: 0.9792
# Epoch 294/2000
# 25/25 [==============================] - 0s 15ms/step - loss: 0.0096 - accuracy: 0.9987 - val_loss: 0.0202 - val_accuracy: 0.9896
# Epoch 295/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0096 - accuracy: 0.9987 - val_loss: 0.0407 - val_accuracy: 0.9896
# Epoch 296/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0094 - accuracy: 0.9987 - val_loss: 0.0498 - val_accuracy: 0.9792
# Epoch 297/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0091 - accuracy: 0.9987 - val_loss: 0.0522 - val_accuracy: 0.9896
# Epoch 298/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0092 - accuracy: 0.9987 - val_loss: 0.0548 - val_accuracy: 0.9896
# Epoch 299/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0089 - accuracy: 0.9987 - val_loss: 0.0122 - val_accuracy: 1.0000
# Epoch 300/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0095 - accuracy: 0.9987 - val_loss: 0.0940 - val_accuracy: 0.9688
# Epoch 301/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0414 - accuracy: 0.9900 - val_loss: 0.1531 - val_accuracy: 0.9583
# Epoch 302/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.1043 - accuracy: 0.9762 - val_loss: 0.2774 - val_accuracy: 0.9062
# Epoch 303/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0845 - accuracy: 0.9825 - val_loss: 0.1480 - val_accuracy: 0.9479
# Epoch 304/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0723 - accuracy: 0.9837 - val_loss: 0.2988 - val_accuracy: 0.9167
# Epoch 305/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0876 - accuracy: 0.9825 - val_loss: 0.2668 - val_accuracy: 0.9062
# Epoch 306/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0538 - accuracy: 0.9900 - val_loss: 0.0924 - val_accuracy: 0.9896
# Epoch 307/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0297 - accuracy: 0.9975 - val_loss: 0.0760 - val_accuracy: 0.9792
# Epoch 308/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0255 - accuracy: 0.9962 - val_loss: 0.1347 - val_accuracy: 0.9583
# Epoch 309/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0266 - accuracy: 0.9962 - val_loss: 0.1017 - val_accuracy: 0.9688
# Epoch 310/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0198 - accuracy: 0.9987 - val_loss: 0.0558 - val_accuracy: 0.9792
# Epoch 311/2000
# 25/25 [==============================] - 0s 15ms/step - loss: 0.0147 - accuracy: 1.0000 - val_loss: 0.0403 - val_accuracy: 0.9896
# Epoch 312/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0131 - accuracy: 1.0000 - val_loss: 0.0268 - val_accuracy: 1.0000
# Epoch 313/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0129 - accuracy: 1.0000 - val_loss: 0.0409 - val_accuracy: 0.9896
# Epoch 314/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0121 - accuracy: 1.0000 - val_loss: 0.0622 - val_accuracy: 0.9896
# Epoch 315/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0119 - accuracy: 1.0000 - val_loss: 0.0294 - val_accuracy: 1.0000
# Epoch 316/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0109 - accuracy: 1.0000 - val_loss: 0.0223 - val_accuracy: 1.0000
# Epoch 317/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0091 - accuracy: 1.0000 - val_loss: 0.0236 - val_accuracy: 0.9896
# Epoch 318/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0091 - accuracy: 1.0000 - val_loss: 0.0761 - val_accuracy: 0.9792
# Epoch 319/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0086 - accuracy: 1.0000 - val_loss: 0.0251 - val_accuracy: 1.0000
# Epoch 320/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0087 - accuracy: 1.0000 - val_loss: 0.0386 - val_accuracy: 0.9896
# Epoch 321/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0101 - accuracy: 1.0000 - val_loss: 0.0316 - val_accuracy: 0.9896
# Epoch 322/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0098 - accuracy: 1.0000 - val_loss: 0.0294 - val_accuracy: 0.9896
# Epoch 323/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0089 - accuracy: 1.0000 - val_loss: 0.0540 - val_accuracy: 0.9688
# Epoch 324/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0104 - accuracy: 0.9987 - val_loss: 0.0407 - val_accuracy: 0.9896
# Epoch 325/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0161 - accuracy: 0.9987 - val_loss: 0.0582 - val_accuracy: 0.9792
# Epoch 326/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0104 - accuracy: 0.9987 - val_loss: 0.0447 - val_accuracy: 0.9792
# Epoch 327/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0082 - accuracy: 0.9987 - val_loss: 0.0361 - val_accuracy: 0.9896
# Epoch 328/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0078 - accuracy: 0.9987 - val_loss: 0.0781 - val_accuracy: 0.9792
# Epoch 329/2000
# ...
# Epoch 559/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 5.0932e-04 - accuracy: 1.0000 - val_loss: 0.0070 - val_accuracy: 1.0000
# Epoch 560/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 5.4130e-04 - accuracy: 1.0000 - val_loss: 0.0057 - val_accuracy: 1.0000
# Epoch 561/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 4.9653e-04 - accuracy: 1.0000 - val_loss: 0.0041 - val_accuracy: 1.0000
# Epoch 562/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 4.8582e-04 - accuracy: 1.0000 - val_loss: 0.0054 - val_accuracy: 1.0000
# Epoch 563/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 4.4833e-04 - accuracy: 1.0000 - val_loss: 0.0041 - val_accuracy: 1.0000
# Epoch 564/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 4.3593e-04 - accuracy: 1.0000 - val_loss: 0.0019 - val_accuracy: 1.0000
# Epoch 565/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 5.0319e-04 - accuracy: 1.0000 - val_loss: 0.0049 - val_accuracy: 1.0000
# Epoch 566/2000
# 25/25 [==============================] - 0s 15ms/step - loss: 4.8832e-04 - accuracy: 1.0000 - val_loss: 0.0012 - val_accuracy: 1.0000
# Epoch 567/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 7.2577e-04 - accuracy: 1.0000 - val_loss: 0.0072 - val_accuracy: 1.0000
# Epoch 568/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 4.3928e-04 - accuracy: 1.0000 - val_loss: 0.0088 - val_accuracy: 0.9896
# Epoch 569/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0018 - accuracy: 0.9987 - val_loss: 0.0429 - val_accuracy: 0.9792
# Epoch 570/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0267 - val_accuracy: 0.9896
# Epoch 571/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0099 - accuracy: 0.9962 - val_loss: 0.3077 - val_accuracy: 0.9271
# Epoch 572/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.1521 - accuracy: 0.9500 - val_loss: 0.6882 - val_accuracy: 0.7396
# Epoch 573/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.1049 - accuracy: 0.9663 - val_loss: 0.4352 - val_accuracy: 0.8750
# Epoch 574/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.1195 - accuracy: 0.9550 - val_loss: 0.1758 - val_accuracy: 0.9583
# Epoch 575/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0697 - accuracy: 0.9750 - val_loss: 0.1009 - val_accuracy: 0.9583
# Epoch 576/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0443 - accuracy: 0.9887 - val_loss: 0.1117 - val_accuracy: 0.9688
# Epoch 577/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0746 - accuracy: 0.9775 - val_loss: 0.1543 - val_accuracy: 0.9375
# Epoch 578/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0525 - accuracy: 0.9812 - val_loss: 0.1130 - val_accuracy: 0.9688
# Epoch 579/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0217 - accuracy: 0.9962 - val_loss: 0.1148 - val_accuracy: 0.9583
# Epoch 580/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0323 - accuracy: 0.9912 - val_loss: 0.0956 - val_accuracy: 0.9688
# Epoch 581/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0148 - accuracy: 0.9975 - val_loss: 0.0813 - val_accuracy: 0.9792
# Epoch 582/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0108 - accuracy: 0.9987 - val_loss: 0.0813 - val_accuracy: 0.9688
# Epoch 583/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0098 - accuracy: 0.9987 - val_loss: 0.0900 - val_accuracy: 0.9792
# Epoch 584/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0182 - accuracy: 0.9962 - val_loss: 0.0899 - val_accuracy: 0.9688
# Epoch 585/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0062 - accuracy: 1.0000 - val_loss: 0.0984 - val_accuracy: 0.9688
# Epoch 586/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0070 - accuracy: 0.9987 - val_loss: 0.0433 - val_accuracy: 0.9792
# Epoch 587/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0055 - accuracy: 1.0000 - val_loss: 0.0802 - val_accuracy: 0.9688
# Epoch 588/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0059 - accuracy: 1.0000 - val_loss: 0.0397 - val_accuracy: 0.9792
# Epoch 589/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0041 - accuracy: 1.0000 - val_loss: 0.0489 - val_accuracy: 0.9792
# Epoch 590/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.0275 - val_accuracy: 0.9896
# Epoch 591/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0022 - accuracy: 1.0000 - val_loss: 0.0445 - val_accuracy: 0.9792
# Epoch 592/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0360 - val_accuracy: 0.9792
# Epoch 593/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.0423 - val_accuracy: 0.9792
# Epoch 594/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.0141 - val_accuracy: 0.9896
# Epoch 595/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.0266 - val_accuracy: 0.9792
# Epoch 596/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0033 - accuracy: 1.0000 - val_loss: 0.0293 - val_accuracy: 0.9792
# Epoch 597/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0397 - val_accuracy: 0.9792
# Epoch 598/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0400 - val_accuracy: 0.9896
# Epoch 599/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0112 - val_accuracy: 1.0000
# Epoch 600/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0289 - val_accuracy: 0.9792
# Epoch 601/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0380 - val_accuracy: 0.9792
# Epoch 602/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0145 - val_accuracy: 1.0000
# Epoch 603/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0134 - val_accuracy: 1.0000
# Epoch 604/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0203 - val_accuracy: 0.9896
# Epoch 605/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0170 - val_accuracy: 0.9896
# Epoch 606/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0122 - val_accuracy: 1.0000
# Epoch 607/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0084 - val_accuracy: 1.0000
# Epoch 608/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0131 - val_accuracy: 1.0000
# Epoch 609/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0173 - val_accuracy: 0.9896
# Epoch 610/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0102 - val_accuracy: 1.0000
# Epoch 611/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 9.2187e-04 - accuracy: 1.0000 - val_loss: 0.0148 - val_accuracy: 1.0000
# Epoch 612/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0010 - accuracy: 1.0000 - val_loss: 0.0151 - val_accuracy: 0.9896
# Epoch 613/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0111 - val_accuracy: 1.0000
# Epoch 614/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 9.4474e-04 - accuracy: 1.0000 - val_loss: 0.0118 - val_accuracy: 1.0000
# Epoch 615/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0297 - val_accuracy: 0.9792
# Epoch 616/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 9.9095e-04 - accuracy: 1.0000 - val_loss: 0.0135 - val_accuracy: 0.9896
# Epoch 617/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0155 - val_accuracy: 0.9896
# Epoch 618/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0095 - val_accuracy: 1.0000
# Epoch 619/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 8.7158e-04 - accuracy: 1.0000 - val_loss: 0.0126 - val_accuracy: 0.9896
# Epoch 620/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0151 - val_accuracy: 0.9896
# Epoch 621/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 8.3915e-04 - accuracy: 1.0000 - val_loss: 0.0085 - val_accuracy: 1.0000
# Epoch 622/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 8.2637e-04 - accuracy: 1.0000 - val_loss: 0.0170 - val_accuracy: 0.9896
# Epoch 623/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 8.5657e-04 - accuracy: 1.0000 - val_loss: 0.0209 - val_accuracy: 0.9896
# Epoch 624/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 8.3681e-04 - accuracy: 1.0000 - val_loss: 0.0166 - val_accuracy: 0.9896
# Epoch 625/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 7.8581e-04 - accuracy: 1.0000 - val_loss: 0.0110 - val_accuracy: 1.0000
# Epoch 626/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0607 - val_accuracy: 0.9792
# Epoch 627/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0049 - accuracy: 0.9987 - val_loss: 0.0161 - val_accuracy: 1.0000
# Epoch 628/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0037 - accuracy: 0.9987 - val_loss: 0.0680 - val_accuracy: 0.9792
# Epoch 629/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0494 - accuracy: 0.9837 - val_loss: 0.1269 - val_accuracy: 0.9375
# Epoch 630/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.1181 - accuracy: 0.9613 - val_loss: 0.4062 - val_accuracy: 0.8750
# Epoch 631/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.1224 - accuracy: 0.9588 - val_loss: 0.0985 - val_accuracy: 0.9583
# Epoch 632/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0316 - accuracy: 0.9900 - val_loss: 0.1174 - val_accuracy: 0.9688
# Epoch 633/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0082 - accuracy: 1.0000 - val_loss: 0.0589 - val_accuracy: 0.9792
# Epoch 634/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0076 - accuracy: 0.9987 - val_loss: 0.0703 - val_accuracy: 0.9792
# Epoch 635/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0040 - accuracy: 1.0000 - val_loss: 0.0476 - val_accuracy: 0.9896
# Epoch 636/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0032 - accuracy: 1.0000 - val_loss: 0.0367 - val_accuracy: 0.9792
# Epoch 637/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0031 - accuracy: 1.0000 - val_loss: 0.0372 - val_accuracy: 0.9896
# Epoch 638/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0026 - accuracy: 1.0000 - val_loss: 0.0310 - val_accuracy: 0.9896
# Epoch 639/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0028 - accuracy: 1.0000 - val_loss: 0.0247 - val_accuracy: 0.9896
# Epoch 640/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.0572 - val_accuracy: 0.9896
# Epoch 641/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.0304 - val_accuracy: 0.9896
# Epoch 642/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0590 - val_accuracy: 0.9896
# Epoch 643/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.0549 - val_accuracy: 0.9688
# Epoch 644/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0030 - accuracy: 1.0000 - val_loss: 0.0460 - val_accuracy: 0.9792
# Epoch 645/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0023 - accuracy: 1.0000 - val_loss: 0.0608 - val_accuracy: 0.9792
# Epoch 646/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0020 - accuracy: 1.0000 - val_loss: 0.0766 - val_accuracy: 0.9792
# Epoch 647/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.0318 - val_accuracy: 0.9896
# Epoch 648/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0335 - val_accuracy: 0.9896
# Epoch 649/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0015 - accuracy: 1.0000 - val_loss: 0.0371 - val_accuracy: 0.9896
# Epoch 650/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0311 - val_accuracy: 0.9896
# Epoch 651/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0430 - val_accuracy: 0.9896
# Epoch 652/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0011 - accuracy: 1.0000 - val_loss: 0.0417 - val_accuracy: 0.9896
# Epoch 653/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0012 - accuracy: 1.0000 - val_loss: 0.0344 - val_accuracy: 0.9896
# Epoch 654/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0014 - accuracy: 1.0000 - val_loss: 0.0420 - val_accuracy: 0.9896
# Epoch 655/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 9.6823e-04 - accuracy: 1.0000 - val_loss: 0.0349 - val_accuracy: 0.9896
# Epoch 656/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0019 - accuracy: 1.0000 - val_loss: 0.0291 - val_accuracy: 0.9896
# Epoch 657/2000
# 25/25 [==============================] - 0s 16ms/step - loss: 0.0021 - accuracy: 1.0000 - val_loss: 0.0293 - val_accuracy: 0.9896
# Epoch 658/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0105 - accuracy: 0.9962 - val_loss: 0.0933 - val_accuracy: 0.9583
# Epoch 659/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0108 - accuracy: 0.9987 - val_loss: 0.0998 - val_accuracy: 0.9688
# Epoch 660/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0114 - accuracy: 0.9975 - val_loss: 0.0549 - val_accuracy: 0.9792
# Epoch 661/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0082 - accuracy: 0.9975 - val_loss: 0.0551 - val_accuracy: 0.9792
# Epoch 662/2000
# 25/25 [==============================] - 0s 13ms/step - loss: 0.0024 - accuracy: 1.0000 - val_loss: 0.0739 - val_accuracy: 0.9792
# Epoch 663/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0018 - accuracy: 1.0000 - val_loss: 0.0301 - val_accuracy: 0.9896
# Epoch 664/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0013 - accuracy: 1.0000 - val_loss: 0.0491 - val_accuracy: 0.9792
# Epoch 665/2000
# 25/25 [==============================] - 0s 14ms/step - loss: 0.0017 - accuracy: 1.0000 - val_loss: 0.0266 - val_accuracy: 0.9896
# Epoch 666/2000
# 23/25 [==========================>...] - ETA: 0s - loss: 0.0017 - accuracy: 1.0000Restoring model weights from the end of the best epoch: 566.
# 25/25 [==============================] - 0s 16ms/step - loss: 0.0016 - accuracy: 1.0000 - val_loss: 0.0238 - val_accuracy: 0.9896
# Epoch 666: early stopping

# %%
acc_metric.reset_states()
acc_metric.update_state(y_test, model(x_test))
acc = acc_metric.result().numpy()
loss = loss_fn(y_test, model(x_test)).numpy()
print(acc, loss)
# Out:
# (100, 54, 512)
# (100, 54, 512)
# (100, 26, 512)
# (100, 26, 512)
# (100, 54, 512)
# (100, 54, 512)
# (100, 26, 512)
# (100, 26, 512)
# 1.0 0.0008677371

# %%
model.summary()
# Out:
# Model: "informer_25"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  global_average_pooling1d_1  multiple                  0
#  3 (GlobalAveragePooling1D)
#
#  dense_221 (Dense)           multiple                  135
#
#  positional_embedding_17 (P  multiple                  15872
#  ositionalEmbedding)
#
# =================================================================
# Total params: 3961991 (15.11 MB)
# Trainable params: 3960967 (15.11 MB)
# Non-trainable params: 1024 (4.00 KB)
# _________________________________________________________________
